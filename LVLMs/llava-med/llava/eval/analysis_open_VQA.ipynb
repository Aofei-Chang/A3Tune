# %%
import argparse
import json
import collections
import random
import pandas as pd    
from nltk.translate.bleu_score import sentence_bleu
from eval_metrics.evaluate_metrics import calculate_exactmatch, calculate_f1score, bleu, calculate_appearance_with_normalization
from tabulate import tabulate
from eval_metrics.glossary import *

def evaluate(gt, pred, return_pred=False):
    bleu_scores = collections.defaultdict(list)
    exact_scores = collections.defaultdict(list)
    f1_scores = collections.defaultdict(list)
    question_analysis = []  # To store detailed scores for each question
    
    num_open = 0
    for gt_item, pred_item in zip(gt, pred):
        try:
            gt_results = gt_item['conversations']
        except KeyError:
            gt_results = gt_item['conversatons']
        if not pred_item.__contains__('gt'):
            pred_item['gt'] = gt_results[1]['value']

        gt_value = gt_results[1]['value'].lower()
        pred_value = pred_item['text'].lower()
        if pred_value.startswith('assistant:'):
            pred_value = pred_value[10:].strip()

        gt_value = normalize_word(gt_value)
        pred_value = normalize_word(pred_value)

        if gt_item['answer_type'] == 'OPEN':
            num_open += 1

            question_id = pred_item['question_id']
            exact_match = calculate_exactmatch(pred_value, gt_value)
            f1, precision, recall = calculate_f1score(pred_value, gt_value)
            bleu = sentence_bleu(references=[str(gt_value).split()], hypothesis=str(pred_value).split())
            bleu_1 = sentence_bleu(references=[str(gt_value).split()], hypothesis=str(pred_value).split(), weights=(1, 0, 0, 0))
            bleu_2 = sentence_bleu(references=[str(gt_value).split()], hypothesis=str(pred_value).split(), weights=(0, 1, 0, 0))
            bleu_3 = sentence_bleu(references=[str(gt_value).split()], hypothesis=str(pred_value).split(), weights=(0, 0, 1, 0))

            # Store detailed scores for each question
            question_analysis.append({
                'question_id': question_id,
                'exact_match': exact_match,
                'f1': f1,
                'precision': precision,
                'recall': recall,
                'bleu': bleu,
                'bleu_1': bleu_1,
                'bleu_2': bleu_2,
                'bleu_3': bleu_3
            })

            exact_scores['hit'].append(exact_match)
            f1_scores['f1'].append(f1)
            f1_scores['precision'].append(precision)
            f1_scores['recall'].append(recall)
            bleu_scores['bleu_score'].append(bleu)
            bleu_scores['bleu_score_1'].append(bleu_1)
            bleu_scores['bleu_score_2'].append(bleu_2)
            bleu_scores['bleu_score_3'].append(bleu_3)

    # Calculate aggregate metrics
    exact_score = sum(exact_scores['hit']) / len(exact_scores['hit']) if num_open else 0
    f1_score = sum(f1_scores['f1']) / len(f1_scores['f1']) if num_open else 0
    precision = sum(f1_scores['precision']) / len(f1_scores['precision']) if num_open else 0
    recall = sum(f1_scores['recall']) / len(f1_scores['recall']) if num_open else 0
    bleu_score = sum(bleu_scores['bleu_score']) / len(bleu_scores['bleu_score']) if num_open else 0
    bleu_score_1 = sum(bleu_scores['bleu_score_1']) / len(bleu_scores['bleu_score_1']) if num_open else 0
    bleu_score_2 = sum(bleu_scores['bleu_score_2']) / len(bleu_scores['bleu_score_2']) if num_open else 0
    bleu_score_3 = sum(bleu_scores['bleu_score_3']) / len(bleu_scores['bleu_score_3']) if num_open else 0

    # Print summary metrics
    print(f'num_open {num_open}')
    print(tabulate(
        [
            ['exact match score', exact_score * 100], 
            ['f1 score', f1_score * 100], 
            ['precision', precision * 100], 
            ['recall', recall * 100], 
            ['bleu_score', bleu_score * 100], 
            ['bleu_score_1', bleu_score_1 * 100], 
            ['bleu_score_2', bleu_score_2 * 100], 
            ['bleu_score_3', bleu_score_3 * 100]
        ], 
        headers=['Metric', 'Performance']
    ))

    # Sort question analysis by lowest F1 score and return the top 30
    low_performance_questions = sorted(question_analysis, key=lambda x: x['f1'])
    if return_pred:
        return low_performance_questions, pred
    return low_performance_questions

def load_jsonl(path):
    data=[]
    with open(path, 'r', encoding='utf-8') as reader:
        for line in reader:
            data.append(json.loads(line))
    return data

# %%
# def eval_open_file(gt_file, pred_file):
visual_enhance_ratio=0.08
bbox_ratio=0.03
epoch_num=6
ROOT_PATH="/data/aofei"
dataset="Slake"

dir=f"llava_med/moe_img_dense_all_query/all_expert_8_16_rank16/lora_{visual_enhance_ratio}_bbox_{bbox_ratio}/epoch{epoch_num}"
gt_file = f"{ROOT_PATH}/hallucination/{dataset}/data/test.json"
pred_file = f"{ROOT_PATH}/hallucination/mitigation/{dataset}/{dir}/inference/pred.jsonl"

dataset = gt_file.split("/")[-2]
print(f"\n========\n {dataset}")

gt = json.load(open(gt_file, 'r'))
# candidate = json.load(open(args.candidate, 'r'))
pred = load_jsonl(pred_file)

gt_ids = [item['id'] for item in gt]
pred_ids = [item['question_id'] for item in pred]
num_gt_ids, num_pred_ids = len(gt_ids), len(pred_ids)
print(f'num_gt_ids: {num_gt_ids} || num_pred_ids: {num_pred_ids}')
# import pdb; pdb.set_trace()
assert gt_ids == pred_ids, "please make sure pred and gt are exactly matched"

# perform evaluation
results = evaluate(gt, pred)
# Out:
# ========
#  data
# num_gt_ids: 1061 || num_pred_ids: 1061
# /data/aofei/conda/env/medh/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /data/aofei/conda/env/medh/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /data/aofei/conda/env/medh/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# num_open 706
# Metric               Performance
# -----------------  -------------
# exact match score       80.5309
# f1 score                80.7272
# precision               81.0188
# recall                  80.971
# bleu_score               3.58223
# bleu_score_1            79.7757
# bleu_score_2            20.3638
# bleu_score_3             5.95555

# %%
len(results)
# Out:
# 706

# %%
results[100]
# Out:
# {'question_id': 12905,
#  'exact_match': 0.0,
#  'f1': 0,
#  'precision': 0,
#  'recall': 0,
#  'bleu': 0,
#  'bleu_1': 0,
#  'bleu_2': 0,
#  'bleu_3': 0}

# %%
pred_dict = dict()
for i in pred:
    pred_dict[i['question_id']] = i

# %%
for i in results[100:200]:
    # print(i, pred_dict[i['question_id']])
    print(pred_dict[i['question_id']])
# Out:
# {'question_id': 12905, 'prompt': '\nHow many femoral heads are shown in this image?', 'text': 'Assistant: 2', 'gt': '0', 'answer_id': 'cbooaNQ8NpeGqipP4wR5HJ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12929, 'prompt': '\nWhich is bigger in this image, small bowel or colon?', 'text': 'Assistant: Colon', 'gt': 'Small Bowel', 'answer_id': 'V9KXwkz6MRUh2abKXmpjXm', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12935, 'prompt': '\nWhat is the function of the organ on the top of this image?', 'text': 'Assistant: Store feces, excrete feces', 'gt': 'Absorb nutrients, secrete enzymes, digest food', 'answer_id': 'iqaALAan5pfvxMjkESfevo', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12938, 'prompt': '\nWhich part of the human body is the organ located in the image?', 'text': 'Assistant: Abdomen', 'gt': 'Pelvic Cavity', 'answer_id': 'Jku53oeNvjtK9VzyKoLWge', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12951, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Brain Edema, Brain Tumor', 'gt': 'None', 'answer_id': 'ERHJ9y2s98F3JRgQdcg4DQ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12968, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Lung Cancer', 'gt': 'None', 'answer_id': 'PtefUpdAG6GFjHnn9mGCf7', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12972, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Abdomen', 'gt': 'Chest', 'answer_id': 'QKagf4ehYRjcnhpiQtQPiA', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12990, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Neck', 'gt': 'Chest', 'answer_id': '7b3aUgK33WCH8XB5o3EZBJ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12991, 'prompt': '\nWhat is the main organ in the image?', 'text': 'Assistant: Brain', 'gt': 'Spinal Cord', 'answer_id': 'MBoQw7MnKaz9P5ELMXhXdt', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12337, 'prompt': '\nHow to treat the disease located on the right of lung in this image?', 'text': 'Assistant: Medical treatment, surgical treatment', 'gt': 'Medical therapy, supportive therapy', 'answer_id': '5iBe4tWg8EeoJdciwFPnR5', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12412, 'prompt': '\nHow to treat the disease located on the upper left of lung in this image?', 'text': 'Assistant: Medical treatment, surgical treatment', 'gt': 'Medical therapy, supportive therapy', 'answer_id': 'fj3NEJuPd7V8LLYQnuGhgD', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12457, 'prompt': '\nHow to treat the disease located on the lower left of lung in this image?', 'text': 'Assistant: Medical treatment, surgical treatment', 'gt': 'Medical therapy, supportive therapy', 'answer_id': '6JWSYBSw6G9gpGxBsFN3Sf', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12387, 'prompt': '\nWhere is/are the abnormality located in this picture?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Upper Right Lung', 'answer_id': 'ChXgithG44ofrCk7tRfuxV', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12462, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Upper Right Lung', 'answer_id': 'DfDpKLFKWr6yEg5uWvK2oC', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12463, 'prompt': '\nWhat part of the lung is the pneumonia located in?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Upper Right Lung', 'answer_id': '7rx8gZmojzJ6C3pBn2TyaD', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12706, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Lower Left Lobe', 'gt': 'Upper Right Lobe', 'answer_id': 'hN6D5bgTV3Fii6BSDpcgfE', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12917, 'prompt': '\nWhat is the effect of the gray organ on the center of this picture?', 'text': 'Assistant: Store feces, excrete feces', 'gt': 'Store urine', 'answer_id': 'd84wDEpsRBZwAJJuzQE5nA', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12930, 'prompt': '\nWhat is the function of the organ on the bottom of this image?', 'text': 'Assistant: Digest food, secrete enzymes', 'gt': 'Digest food, absorb water, excrete body waste', 'answer_id': 'TAwLEyuD9eVFBMhQgHAydD', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12472, 'prompt': '\nHow to prevent the occurrence of the disease on the upper right lobe of lung in this image?', 'text': 'Assistant: Quit smoking, enhance physical fitness', 'gt': 'Pay attention to prevent cold and keep warm, enhance physical fitness', 'answer_id': 'gZPkKnzsntWR3RYrXPbVHu', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12487, 'prompt': '\nHow to prevent the occurrence of the disease on the lower right lobe of lung in this image?', 'text': 'Assistant: Quit smoking, enhance physical fitness', 'gt': 'Pay attention to prevent cold and keep warm, enhance physical fitness', 'answer_id': 'GVPcmjPZDHhyCtQzUaq2ta', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12144, 'prompt': '\nWhere is the liver?', 'text': 'Assistant: Upper Left', 'gt': 'Left and top', 'answer_id': 'HNAjeiPwaJYD6Sz5db3h8y', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12312, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Right Lung', 'gt': 'Lower Left Lung', 'answer_id': 'dsWTadKsqBVorUwKpvWjSo', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12328, 'prompt': '\nWhere is the pneumonia in the lung?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Right Lung', 'answer_id': 'FTdiqFoo8dfdnu7iNygwt8', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12373, 'prompt': '\nWhere is the pulmonary nodule located in this image?', 'text': 'Assistant: Right Lung', 'gt': 'Lower Left Lung', 'answer_id': 'ijyBLhVR4tcw9xdAuqnRpY', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12418, 'prompt': '\nWhere is the pneumothorax in this image?', 'text': 'Assistant: Right Lung', 'gt': 'Lower Left Lung', 'answer_id': 'acmByJApeym5ecwkRHbvhr', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12732, 'prompt': '\nWhere is the brain tumor?', 'text': 'Assistant: Upper Right Lobe', 'gt': 'Left Lobe', 'answer_id': 'TuprngpVJaJC4ZTCedyjUV', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12776, 'prompt': '\nWhere are the abnormalities in this image?', 'text': 'Assistant: Right Lobe', 'gt': 'Lower Left Lobe', 'answer_id': 'g9zqQTfgD2JeJRySdeUG9Q', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12810, 'prompt': '\nWhich organs/organ is part of the digestive system in this image?', 'text': 'Assistant: Colon, Small Bowel', 'gt': 'Stomach, Colon', 'answer_id': 'ZgZGeWuEGi4DHodC8EtP5G', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12640, 'prompt': '\nWhat kind of symptoms will the disease on the left lobe of brain in the picture bring to the patient?', 'text': 'Assistant: Encephalomalacia, local edema, confusion, increased intracranial pressure', 'gt': 'Visual impairment, vomiting, tinnitus, increased intracranial pressure', 'answer_id': 'FpncjJGCSo8LAqpxQQ6hBv', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12942, 'prompt': '\nWhat is the effect of the organ on the left of this picture?', 'text': 'Assistant: Absorb nutrients, secrete enzymes, digest food', 'gt': 'Digest food, absorb water, excrete body waste', 'answer_id': 'MGSbqNsmQPKfWwJXmrvg23', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11936, 'prompt': '\nWhat is the main organ in the image?', 'text': 'Assistant: Lung', 'gt': 'Lung, Spinal Cord', 'answer_id': 'HUPnPxTnLcavhpUaQbCi7q', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12127, 'prompt': '\nWhere is the liver?', 'text': 'Assistant: Left', 'gt': 'Left and top', 'answer_id': '7yKjZ9k32zCfG8Fwgq6KUH', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12186, 'prompt': '\nWhat is the organ on the top of the body in this image?', 'text': 'Assistant: Heart', 'gt': 'Heart and Liver', 'answer_id': 'aZYo6XYAxhNxPm9uDPmJX7', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12301, 'prompt': '\nWhat disease is/are shown on the left of lung?', 'text': 'Assistant: Pulmonary Nodule', 'gt': 'Pulmonary Mass', 'answer_id': 'dkf4VrucLvDtxAPJqCynsZ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12433, 'prompt': '\nWhere is/are the nodule located in this image?', 'text': 'Assistant: Right Lung', 'gt': 'Left Lung', 'answer_id': 'K8ijW3ivDvUky6nsPUCYD7', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12532, 'prompt': '\nWhat kind of symptoms will the disease on the lower left of lung bring to the patient?', 'text': 'Assistant: Cough foamy mucus sputum, dyspnea, cough, chest pain', 'gt': 'Chest tightness, dyspnea, chest pain', 'answer_id': 'CL92iS7Pq3aD3ooKWFbfiK', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12715, 'prompt': '\nWhere are the abnormalities in this image?', 'text': 'Assistant: Right Lobe', 'gt': 'Left Lobe', 'answer_id': 'ZRr4uRPXxS9hTbkyLB2aWH', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12751, 'prompt': '\nWhere is the brain non-enhancing tumor?', 'text': 'Assistant: Right Lobe', 'gt': 'Left Lobe', 'answer_id': '9i7XGhsGHCeF7Wh7aBcnhL', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12918, 'prompt': '\nWhich organs/organ is part of the digestive system in this image?', 'text': 'Assistant: Rectum, Small Bowel', 'gt': 'Rectum', 'answer_id': '8aGH8ihrKCHc9NQCW3qBRC', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12939, 'prompt': '\nWhere is colon in this image?', 'text': 'Assistant: Upper Right', 'gt': 'Upper Left', 'answer_id': '2Z8zscwHS7tqK9r5DnFvhq', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12973, 'prompt': '\nWhat is the main organ in the image?', 'text': 'Assistant: Liver, Heart, Spleen', 'gt': 'Liver', 'answer_id': 'nkBNmtCzBCHBiNGbeowiUd', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12277, 'prompt': '\nWhat kind of symptoms will the disease on the upper right of lung bring to the patient?', 'text': 'Assistant: Chest pain, cough, expectoration', 'gt': 'Chest pain, dyspnea', 'answer_id': 'NoLdHpsghh7u9gVLggomiA', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12691, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Brain Edema', 'gt': 'Brain Edema, Brain Non-enhancing Tumor', 'answer_id': 'aeAW3bW23GH6DB2d7CsGmG', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12367, 'prompt': '\nHow to prevent the occurrence of the disease on the lower left lobe of lung in this image?', 'text': 'Assistant: Quit smoking, enhance physical fitness', 'gt': 'Live healthy, enhance physical fitness', 'answer_id': 'BniJdNx3ZjXSia3Gi2wgYv', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12502, 'prompt': '\nWhat kind of symptoms will the disease on the lower left of lung bring to the patient?', 'text': 'Assistant: Cough foamy mucus sputum, dyspnea, cough, chest pain', 'gt': 'Chest pain, cough, expectoration', 'answer_id': 'TjVXDHDTYcCyXK7KUM7CN3', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12169, 'prompt': '\nWhat is the organ on the left side of this image?', 'text': 'Assistant: Right Lung', 'gt': 'Lung', 'answer_id': '3V52P8Ev4uJFz98Ar8KwAu', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12216, 'prompt': '\nWhere is the liver?', 'text': 'Assistant: Upper Left', 'gt': 'Left', 'answer_id': 'kevNTrzsMpE8u3HQZx8R6w', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12282, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Lower Right Lung', 'answer_id': '68eYwoCRri87hoPRJ4z5tq', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12283, 'prompt': '\nWhere is the atelectasis in this image?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Lower Right Lung', 'answer_id': 'RXoL8KFFHTyfgrBRMDNKZ3', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12298, 'prompt': '\nWhere is the mass in this image?', 'text': 'Assistant: Upper Left Lung', 'gt': 'Lower Left Lung', 'answer_id': '7haPi4p8nLmnf662m2UutJ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12402, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Upper Left Lung', 'answer_id': 'JwTwdmJrEF4tFtifJZxHLS', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12478, 'prompt': '\nWhere is the pneumonia in the lung?', 'text': 'Assistant: Lower Left Lung', 'gt': 'Lower Right Lung', 'answer_id': '8psoXZUAzv7i2Tbq626fZq', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12523, 'prompt': '\nWhere is the pleural effusion?', 'text': 'Assistant: Lower Left Chest', 'gt': 'Lower Left Lung', 'answer_id': '6oLsnCSMDzfTFLAUzGguqJ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12654, 'prompt': '\nWhere are the abnormalities in this image?', 'text': 'Assistant: Upper Right Lobe', 'gt': 'Upper Left Lobe', 'answer_id': '4tui4pUyeLxAGfK5hgMD2W', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12664, 'prompt': '\nWhere is the brain tumor?', 'text': 'Assistant: Lower Left Lobe', 'gt': 'Upper Left Lobe', 'answer_id': 'c4uZhG5Dxw2GKLdREDXBjQ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12672, 'prompt': '\nWhere is the brain tumor?', 'text': 'Assistant: Lower Right Lobe', 'gt': 'Upper Right Lobe', 'answer_id': '7qC7ZzcQrGGtGBaNEVKJ3o', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12681, 'prompt': '\nWhere is the brain tumor?', 'text': 'Assistant: Lower Right Lobe', 'gt': 'Upper Right Lobe', 'answer_id': 'cVQLzsJAxyeCHticNixt6b', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12724, 'prompt': '\nWhere is the brain tumor located?', 'text': 'Assistant: Lower Right Lobe', 'gt': 'Lower Left Lobe', 'answer_id': 'gkk2jvUXm5YwVMwmgxV3xK', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12741, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Lower Right Lobe', 'gt': 'Lower Left Lobe', 'answer_id': 'Vt5Xkoi5FqxS6pPRZb7RKa', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12834, 'prompt': '\nWhere is the liver in this image?', 'text': 'Assistant: Upper Left', 'gt': 'Left', 'answer_id': '3TKj63dqyhjfM6KdCtnagD', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12006, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'gt': 'Right Lung', 'answer_id': 'RpStb2A8gZJBRYgh4QCXw9', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12071, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung', 'gt': 'Right Lung, Left', 'answer_id': 'gSY3YTrudNGyaRiFTqYDhS', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12268, 'prompt': '\nWhat part of the lung is the pneumothorax located in?', 'text': 'Assistant: Right Lung', 'gt': 'Upper Right Lung', 'answer_id': 'bn2TBFfic7mGqPrQ8YCu5C', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12403, 'prompt': '\nWhat part of the lung is the pneumothorax located in?', 'text': 'Assistant: Left Lung', 'gt': 'Upper Left Lung', 'answer_id': '4LPVhnAi6hkXt3gymUGoXr', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12538, 'prompt': '\nWhich organs appear in pairs?', 'text': 'Assistant: Temporal Lobe, Eyes', 'gt': 'Temporal Lobe', 'answer_id': 'Wggk7UDPx7FA6M8AmqVKWf', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12874, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Brain Edema, Brain Enhancing Tumor, Brain Non-enhancing Tumor', 'gt': 'Brain Tumor, Brain Edema', 'answer_id': 'YLzJFiqDyDMpAhPJBNrSQW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11985, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'gt': 'Left Lung, Lower Right', 'answer_id': 'catCpeMCkbx4vBnotqESuj', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12044, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'gt': 'Right Lung, Lower Left', 'answer_id': '6V5sjJPJSWoVPpDYGSujDz', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 12743, 'prompt': '\nWhat disease is/are shown on the lower left of brain?', 'text': 'Assistant: Brain Edema, Brain Enhancing Tumor, Brain Non-enhancing Tumor', 'gt': 'Brain Edema, Brain Enhancing Tumor', 'answer_id': 'dGU3nq6ZLDvqhmtUiqWh2K', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11934, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: CT', 'gt': 'CT', 'answer_id': 'G3nxwdunAYnP3PHWQjUQFx', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11935, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Chest', 'gt': 'Chest', 'answer_id': 'EC3sHuDcoUCxisK7CcsS7b', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11937, 'prompt': '\nWhat is the largest organ in the picture?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': '6VfqVu6zDc7P2narwJ7SQ3', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11943, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'gt': 'Left Lung, Right', 'answer_id': 'k26qMzNPzwMaytgxGHiWzi', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11944, 'prompt': '\nWhich is the biggest in this image,lung,liver or heart?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': 'Gsn9RWhJGw3Xw8DJXjvkEG', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11945, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: CT', 'gt': 'CT', 'answer_id': 'FMXxjYJsjEqLjBDamTxXW8', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11946, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Chest', 'gt': 'Chest', 'answer_id': 'E2VSJDvooeKLB2XWixcNew', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11947, 'prompt': '\nWhat is the main organ in the image?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': '2oBV8dpCKhmqzgYZWS4dEW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11948, 'prompt': '\nWhat is the largest organ in the picture?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': 'M8MguoSjWHt456HAfVJcpT', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11953, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'gt': 'Left Lung, Right', 'answer_id': 'ekE8XrKf9GBnxvrft9gUh7', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11954, 'prompt': '\nWhich is the biggest in this image,lung,liver or heart?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': 'XW7VAwZTDNoAK8V9raHPWr', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11955, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: CT', 'gt': 'CT', 'answer_id': 'L94L2yfK5anrUCXUN82nXW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11956, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Chest', 'gt': 'Chest', 'answer_id': '6b62GreCRaaXouMqQrYqK8', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11957, 'prompt': '\nWhat is the main organ in the image?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': 'TMnq9FzVRVzvQwkZzjQFGj', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11958, 'prompt': '\nWhat is the largest organ in the picture?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': 'SNkpuW8RTGcX5rjyBo6GuN', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11962, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Lung Cancer', 'gt': 'Lung Cancer', 'answer_id': 'XN6XQSFFVuwq8g54oWw9kk', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11964, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'gt': 'Right Lung, Left', 'answer_id': 'WiH7HMdT3gmPmZarpcEVGW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11965, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: X-Ray', 'gt': 'X-Ray', 'answer_id': 'ETqiTMaTireJJfShcg5Z8q', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11966, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Chest', 'gt': 'Chest', 'answer_id': 'CZC7QNcnCr7EqZhCkzJs84', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11967, 'prompt': '\nWhat is the largest organ in the picture?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': '36wmWhSmYzBLjZ88VGwQ8D', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11972, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: MRI', 'gt': 'MRI', 'answer_id': 'KoEKAwTiw5oDQFDyyE5F9Q', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11973, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Abdomen', 'gt': 'Abdomen', 'answer_id': 'C2KyGuLCbeurW5bBvsi8Mh', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11974, 'prompt': '\nWhat is the mr weighting in this image?', 'text': 'Assistant: T2', 'gt': 'T2', 'answer_id': 'Bo4CL9GUtdzST9sokxscQW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11980, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: X-Ray', 'gt': 'X-Ray', 'answer_id': 'EtxkKf5ZE6S34vTL8szHX5', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11981, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Chest', 'gt': 'Chest', 'answer_id': 'A8TMYXtLe874ELXHxhwbbM', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11983, 'prompt': '\nWhat is the largest organ in the picture?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': 'DqRbAYYPBu4Uvy2ntYr9Uc', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11984, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Pneumonia', 'gt': 'Pneumonia', 'answer_id': 'a2HRDTTFSWHT5okSSVXwK9', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11987, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: X-Ray', 'gt': 'X-Ray', 'answer_id': 'PguzxUdE6rQzEoy8enMRqu', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11988, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Chest', 'gt': 'Chest', 'answer_id': 'mHwWRknaUDwp32mfz7z4He', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11990, 'prompt': '\nWhat is the largest organ in the picture?', 'text': 'Assistant: Lung', 'gt': 'Lung', 'answer_id': '3eDsqspvPUjdwB2Csmgas2', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}
# {'question_id': 11991, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Cardiomegaly', 'gt': 'Cardiomegaly', 'answer_id': 'EchTriFR7NCLUdG3zb3DK4', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}}

# %%
# def eval_open_file(gt_file, pred_file):
visual_enhance_ratio=0.08
bbox_ratio=0.03
epoch_num=6
ROOT_PATH="/data/aofei"
dataset="Slake"

# dir=f"llava_med/moe_img_dense_all_query/all_expert_8_16_rank16/lora_{visual_enhance_ratio}_bbox_{bbox_ratio}/epoch{epoch_num}"
gt_file = f"{ROOT_PATH}/hallucination/{dataset}/data/test.json"
# pred_file = f"{ROOT_PATH}/hallucination/mitigation/{dataset}/{dir}/inference/pred.jsonl"

dataset = gt_file.split("/")[-2]
print(f"\n========\n {dataset}")

pred_file = "/data/aofei/hallucination/mitigation/Slake/llava_med/lora/epoch6/inference/pred.jsonl"

gt = json.load(open(gt_file, 'r'))
# candidate = json.load(open(args.candidate, 'r'))
pred = load_jsonl(pred_file)

gt_ids = [item['id'] for item in gt]
pred_ids = [item['question_id'] for item in pred]
num_gt_ids, num_pred_ids = len(gt_ids), len(pred_ids)
print(f'num_gt_ids: {num_gt_ids} || num_pred_ids: {num_pred_ids}')
# import pdb; pdb.set_trace()
assert gt_ids == pred_ids, "please make sure pred and gt are exactly matched"

# perform evaluation
results_lora, pred = evaluate(gt, pred, return_pred=True)

pred_dict = dict()
for i in pred:
    pred_dict[i['question_id']] = i
# Out:
# ========
#  data
# num_gt_ids: 1061 || num_pred_ids: 1061
# num_open 706
# Metric               Performance
# -----------------  -------------
# exact match score       81.9666
# f1 score                82.2
# precision               82.5391
# recall                  82.5009
# bleu_score               4.00716
# bleu_score_1            81.1315
# bleu_score_2            21.2204
# bleu_score_3             6.22461

# %%
for i in results_lora[:100]:
    print(pred_dict[i['question_id']])
# Out:
# {'question_id': 11968, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Infiltration', 'answer_id': 'Xw2YyEKn2KtquKweHeyuoh', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Cardiomegaly'}
# {'question_id': 11969, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Right Lung, Upper Left', 'answer_id': 'TZrRYtWLU48C8YdVnRwvPV', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Center'}
# {'question_id': 11971, 'prompt': '\nWhich organ is abnormal, heart or lung?', 'text': 'Assistant: Lung', 'answer_id': 'kh2GKdDXJbT29xcrXaVqRq', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Heart'}
# {'question_id': 11984, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Atelectasis', 'answer_id': 'oPcg6bnQUBs398vLktmauT', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pneumonia'}
# {'question_id': 11991, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Mass', 'answer_id': 'Rqyji4pxCP9idFfiCnRPRu', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Cardiomegaly'}
# {'question_id': 11992, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'answer_id': 'eS76FPAyReoMMroZ3e3oEX', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Center'}
# {'question_id': 11993, 'prompt': '\nWhich organ is abnormal, heart or lung?', 'text': 'Assistant: Lung', 'answer_id': 'gByHufuJVrt649roP8K6U2', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Heart'}
# {'question_id': 11998, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Infiltration', 'answer_id': 'E8AcMQskwspmX4S8t8g2Hy', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Cardiomegaly'}
# {'question_id': 12000, 'prompt': '\nWhich organ is abnormal, heart or lung?', 'text': 'Assistant: Lung', 'answer_id': 'MYKgYSJr4uq5C3ebzFee9F', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Heart'}
# {'question_id': 12005, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Cardiomegaly', 'answer_id': 'gk3MncQTD5h3uMpEWtP87S', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Atelectasis, Mass'}
# {'question_id': 12015, 'prompt': '\nWhich organ is abnormal, heart or lung?', 'text': 'Assistant: Lung', 'answer_id': 'dttxh5GPrrSY3T8CfSt5P8', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Heart'}
# {'question_id': 12021, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Left Lung, Right', 'answer_id': 'XYx8QYXXiLkvWYzVyEXSqY', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Center'}
# {'question_id': 12022, 'prompt': '\nWhich organ is abnormal, heart or lung?', 'text': 'Assistant: Lung', 'answer_id': 'f2ncCRwkTnV9ir4hQcqTou', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Heart'}
# {'question_id': 12027, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Atelectasis', 'answer_id': 'V5ND6i9vciHvR9YQdMCpkb', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Nodule'}
# {'question_id': 12034, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Atelectasis', 'answer_id': 'GYkzLHXzkNaD4CKMHWLfrb', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Nodule'}
# {'question_id': 12043, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Pneumonia', 'answer_id': 'LFsgKePqz4uGjv3CaKVogD', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Atelectasis'}
# {'question_id': 12050, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Pneumothorax', 'answer_id': 'XnHESxWof9WzA7pchqSmdf', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pneumonia'}
# {'question_id': 12058, 'prompt': '\nHow many kidneys are there in this image?', 'text': 'Assistant: 2', 'answer_id': '89XPzS6GKyYpYFnhj2xcZe', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '1'}
# {'question_id': 12070, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Atelectasis', 'answer_id': '9rMhZChfMkSCGa3HMN3whJ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pneumothorax'}
# {'question_id': 12071, 'prompt': '\nWhere is/are the abnormality located?', 'text': 'Assistant: Center', 'answer_id': 'dTwMf2SEMYc8rvabKrnMyk', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Right Lung, Left'}
# {'question_id': 12086, 'prompt': '\nWhich is bigger in this image, kidney or liver?', 'text': 'Assistant: Kidney', 'answer_id': 'SQVfgk9ygrTmnm3Hq6ZpJn', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Liver'}
# {'question_id': 12100, 'prompt': '\nWhere is the liver?', 'text': 'Assistant: Upper Left', 'answer_id': 'JQmqUJ5so2wfWsk9t7trQv', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Top'}
# {'question_id': 12129, 'prompt': '\nHow many kidneys in this image?', 'text': 'Assistant: 2', 'answer_id': 'T5QkTVH8ceMHVTcsRfV36z', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '0'}
# {'question_id': 12130, 'prompt': '\nWhich is bigger in this image, kidney or spleen?', 'text': 'Assistant: Spleen', 'answer_id': 'Md9RwpK7c7z57UbQBugYNW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Liver'}
# {'question_id': 12146, 'prompt': '\nHow many kidneys in this image?', 'text': 'Assistant: 0', 'answer_id': '62wkVJ9d6UmYXe8XjYyn3p', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '2'}
# {'question_id': 12150, 'prompt': '\nWhich is bigger in this image, liver or spleen?', 'text': 'Assistant: Liver', 'answer_id': 'NVYmEDGRoHLBZ5qJqcYdHb', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Spleen'}
# {'question_id': 12167, 'prompt': '\nWhere is the liver?', 'text': 'Assistant: Upper Left', 'answer_id': 'jD23vqQuZRpnepNcxB9acp', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Not seen'}
# {'question_id': 12205, 'prompt': '\nWhat is the shape of the kidney in the picture?', 'text': 'Assistant: Oval', 'answer_id': 'kcpmVSQUvgnse2r47XN4oQ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Irregular'}
# {'question_id': 12216, 'prompt': '\nWhere is the liver?', 'text': 'Assistant: Top', 'answer_id': 'U3jvmbbW4FAWgmvZmNZWoG', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Left'}
# {'question_id': 12220, 'prompt': '\nWhat are the white spots in the black part of the lower part of body?', 'text': 'Assistant: Symmetrical to the Liver', 'answer_id': '2DLrHxyjETyJZv2u8kjMBr', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pulmonary bronchus'}
# {'question_id': 12231, 'prompt': '\nWhat organ is the gray part on the left of the image?', 'text': 'Assistant: Liver', 'answer_id': 'f9GegkpJTYMrNtedSzVb2M', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Large Bowel'}
# {'question_id': 12243, 'prompt': '\nWhat is the rightmost organ in this image?', 'text': 'Assistant: Left Lung', 'answer_id': 'Y5krwP3jUwoSqzsndfJQAh', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Large Bowel'}
# {'question_id': 12248, 'prompt': '\nWhat organ is the black hole in the upper right corner?', 'text': 'Assistant: Stomach', 'answer_id': 'Zzp2W6HLJ6t76FrGujPowd', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Large Bowel'}
# {'question_id': 12259, 'prompt': '\nWhat is the rightmost organ in this image?', 'text': 'Assistant: Spleen', 'answer_id': 'mNDwgbGJgfTwRH4tuGuuTh', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Large Bowel'}
# {'question_id': 12263, 'prompt': '\nWhat organ is the black hole in the upper right corner?', 'text': 'Assistant: Stomach', 'answer_id': 'fCNoGNG2JdbyXicCfGPKRJ', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Large Bowel'}
# {'question_id': 12282, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Heart', 'answer_id': 'YYB3N6bZuKLZitnAdsXmnm', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Lower Right Lung'}
# {'question_id': 12292, 'prompt': '\nWhat is the main cause of the disease on the lower right of the lung in the picture?', 'text': 'Assistant: Inflammation, malignant tumor, trauma, etc', 'answer_id': 'c5nFAR7sdFG9UkzBuNu2pm', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Bronchial obstruction'}
# {'question_id': 12297, 'prompt': '\nWhich side of lung is abnormal in this image,left or right?', 'text': 'Assistant: Right', 'answer_id': 'KjcCTQNvtrbJbQ9sm8w3xW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Left'}
# {'question_id': 12307, 'prompt': '\nHow to prevent the occurrence of the disease on the lower left lobe of lung in this image?', 'text': 'Assistant: Quit smoking, enhance physical fitness', 'answer_id': '2n5yEiuvBxVpYDxCxTBq7h', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Keep healthy'}
# {'question_id': 12312, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Heart', 'answer_id': '7kzh3MH8mNS4P2ooKstcDu', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Lower Left Lung'}
# {'question_id': 12331, 'prompt': '\nWhat disease is/are shown on the right of lung?', 'text': 'Assistant: Pulmonary Mass', 'answer_id': 'nHsjNzsPgj4VLFaadyg7LW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pneumonia'}
# {'question_id': 12357, 'prompt': '\nWhich lobe is abnormal in this image?', 'text': 'Assistant: Right', 'answer_id': '9STDhfvYrdq4YTumDaWurW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Left'}
# {'question_id': 12362, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Pneumothorax', 'answer_id': '7BB86CnYCFotEZjCF9WUno', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pulmonary Infiltration'}
# {'question_id': 12372, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Heart', 'answer_id': 'G7qqxCJDuPy5DXNUn36dXm', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Lower Left Lung'}
# {'question_id': 12417, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Heart', 'answer_id': 'UrdkLFnK8bjwaAvCZDogwq', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Lower Left Lung'}
# {'question_id': 12418, 'prompt': '\nWhere is the pneumothorax in this image?', 'text': 'Assistant: Right Chest', 'answer_id': '3eEke7kRSKgrt6jU9uYGzA', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Lower Left Lung'}
# {'question_id': 12427, 'prompt': '\nWhat is the main cause of the disease on the lower left of the lung in the picture?', 'text': 'Assistant: Bronchial obstruction', 'answer_id': 'DqGiPshkoP4HbKS5Ffve29', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Chest injury, lung disease, bullae'}
# {'question_id': 12442, 'prompt': '\nHow to prevent the occurrence of the disease on the left lobe of lung in this image?', 'text': 'Assistant: Keep healthy', 'answer_id': 'eWGRfNSQqTow3CX2eaxxpK', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Quit smoking, enhance physical fitness'}
# {'question_id': 12462, 'prompt': '\nWhere is the abnormality in this image?', 'text': 'Assistant: Heart', 'answer_id': 'kK3Q7XtUseqm9ErMJubyNs', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Upper Right Lung'}
# {'question_id': 12477, 'prompt': '\nWhich side of lung is abnormal in this image?', 'text': 'Assistant: Both', 'answer_id': 'dBzADC6K2FLd8bV3nf6cKj', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Right'}
# {'question_id': 12481, 'prompt': '\nWhat disease is/are shown on the right of lung?', 'text': 'Assistant: Pulmonary Nodule', 'answer_id': 'i668ZyXTLh6t8mJsEwFisA', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pneumonia'}
# {'question_id': 12492, 'prompt': '\nWhich side of lung is abnormal in this image?', 'text': 'Assistant: Right', 'answer_id': 'e6fbYSZhi3oXzGeZEbQ2FF', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Left'}
# {'question_id': 12497, 'prompt': '\nWhat disease is/are shown on the lower left of lung?', 'text': 'Assistant: Atelectasis', 'answer_id': 'kvKs78bFvX7R73tzPnkdSM', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pulmonary Infiltration'}
# {'question_id': 12507, 'prompt': '\nWhich part of chest is abnormal in this image?', 'text': 'Assistant: Heart', 'answer_id': 'JRvcvDD9ZpXj27UXZKJ7CW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Lower Left Lung'}
# {'question_id': 12517, 'prompt': '\nWhat is the main cause of the disease on the lower left of the lung in the picture?', 'text': 'Assistant: Bronchial obstruction', 'answer_id': 'aSrARwqYaZMjpbPHze5gvH', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Inflammation, malignant tumor, trauma, etc'}
# {'question_id': 12526, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Cardiomegaly', 'answer_id': 'PxjCVgc4dXRxuG35KyHUB3', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pleural Effusion'}
# {'question_id': 12544, 'prompt': '\nHow many ears are shown in this image?', 'text': 'Assistant: 2', 'answer_id': 'Zs97exCMTsynKtKLPmqize', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '0'}
# {'question_id': 12552, 'prompt': '\nWhere is the brain stem in this image?', 'text': 'Assistant: Top', 'answer_id': 'QnmgAPkBns57nTKFHWaZHr', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Center'}
# {'question_id': 12560, 'prompt': '\nWhat is the function of the tissue on the center of this image?', 'text': 'Assistant: Ventilation, pronunciation', 'answer_id': '5V5hu5ksPefG9tDrjpTYJG', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Control heartbeat and breathing'}
# {'question_id': 12584, 'prompt': '\nWhat is the shape of larynx in this image?', 'text': 'Assistant: Irregular', 'answer_id': '3cXFyii9QFG3CdDG8v2wZ6', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Oval'}
# {'question_id': 12590, 'prompt': '\nWhere does the image represent in the body?', 'text': 'Assistant: Head', 'answer_id': 'ZMvXiwUqsRef5vTrpV4s3A', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Neck'}
# {'question_id': 12592, 'prompt': '\nWhat organ system is primarily present in this image?', 'text': 'Assistant: Head', 'answer_id': 'eS6AJBohrzi2iWD7z6ZDx9', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Neck'}
# {'question_id': 12598, 'prompt': '\nWhich organs/organ in the picture belong to the respiratory system?', 'text': 'Assistant: Larynx', 'answer_id': 'ZXjJmJoj2avBadebLnns2C', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Trachea'}
# {'question_id': 12608, 'prompt': '\nWhat is the shape of trachea about this patient?', 'text': 'Assistant: Circular', 'answer_id': 'cJZA6jo5M2bcmaw5GJodcP', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Irregular'}
# {'question_id': 12619, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: None', 'answer_id': 'N5bgsAzRpQnwmCJDA7ZPjP', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Brain Edema, Brain Enhancing Tumor'}
# {'question_id': 12620, 'prompt': '\nHow many kinds of abnormalities are there in this image?', 'text': 'Assistant: 1', 'answer_id': 'DvYtJFtuwSuRbWfniLuMYw', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '2'}
# {'question_id': 12648, 'prompt': '\nHow many kinds of abnormalities are there in this image?', 'text': 'Assistant: 3', 'answer_id': 'KarCc3jQtEHnFacTjnyYyp', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '1'}
# {'question_id': 12649, 'prompt': '\nHow to treat the most severe disease in this image?', 'text': 'Assistant: Medical treatment, supportive treatment, surgical treatment', 'answer_id': 'mtb5D9DYRaRkPgfoKnsXKY', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pharmacotherapy, rehabilitation'}
# {'question_id': 12651, 'prompt': '\nIs this a T1 weighted or T2 weighted MRI image?', 'text': 'Assistant: T1', 'answer_id': 'kGtpmJ4dwBCix4fWPfU6Rz', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'T2'}
# {'question_id': 12657, 'prompt': '\nIs the abnormality hyperdense or hypodense?', 'text': 'Assistant: Hypodense', 'answer_id': 'YSXW8yM96b8trtGc2mqurc', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Hyperdense'}
# {'question_id': 12659, 'prompt': '\nHow to treat the most severe disease in this image?', 'text': 'Assistant: Medical treatment, supportive treatment, surgical treatment', 'answer_id': '777xxtbbNXgpPacGErzRx6', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Pharmacotherapy, rehabilitation'}
# {'question_id': 12663, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Brain', 'answer_id': 'D4pSbj5wVkZsxU7GNMVwS6', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Head'}
# {'question_id': 12671, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Brain', 'answer_id': 'H79aheZHC58TnUejogZwbH', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Head'}
# {'question_id': 12675, 'prompt': '\nIs the abnormality hyperdense or hypodense?', 'text': 'Assistant: Hypodense', 'answer_id': 'GafwoNDpX7gmF2yvqEGX2j', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Hyperdense'}
# {'question_id': 12695, 'prompt': '\nWhat is the mr weighting in this image?', 'text': 'T1', 'answer_id': '4f8sbxgFEKS6dF3ejzQ77V', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'T2'}
# {'question_id': 12699, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: None', 'answer_id': 'FVAeBt5aHf5RjrX8izZESG', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Brain Edema'}
# {'question_id': 12703, 'prompt': '\nWhich kind of weighting is this image generated with, t1 or t2?', 'text': 'Assistant: T2', 'answer_id': 'bs3BV4G6oHvNeV9x7WzP9G', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'T1'}
# {'question_id': 12705, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Brain', 'answer_id': 'RjaoaAojtE3KxVsevDxybA', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Head'}
# {'question_id': 12718, 'prompt': '\nIs the brain enhancing tumor hyperdense or hypodense?', 'text': 'Assistant: Hypodense', 'answer_id': '2zFN5GTv54sRmo67htbwou', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Hyperdense'}
# {'question_id': 12745, 'prompt': '\nHow many kinds of abnormalities are there in this image?', 'text': 'Assistant: 3', 'answer_id': 'A9hC9xYyXXq2a5mSYsNFv8', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '2'}
# {'question_id': 12754, 'prompt': '\nHow many kinds of abnormalities are there in this image?', 'text': 'Assistant: 3', 'answer_id': '7bXRipthzJZvPRMEgxQHsr', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '2'}
# {'question_id': 12779, 'prompt': '\nHow many kinds of abnormalities are there in this image?', 'text': 'Assistant: 3', 'answer_id': 'JgEgHB6qsmmQ6neaYbtBso', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '1'}
# {'question_id': 12786, 'prompt': '\nWhich is smaller in this image,liver or right kidney?', 'text': 'Assistant: Liver', 'answer_id': 'XeDVKRjhycRKFY9eobJDbH', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Right Kidney'}
# {'question_id': 12789, 'prompt': '\nWhich organs/organ is part of the lymphatic system in this image?', 'text': 'Assistant: Colon', 'answer_id': 'YPjXSPXkPmuQpxeKXrApWW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Spleen'}
# {'question_id': 12799, 'prompt': '\nHow many lungs have existed in this image?', 'text': 'Assistant: 0', 'answer_id': 'PbrfM4ZvAGBXmjatTtyzHW', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '2'}
# {'question_id': 12800, 'prompt': '\nWhat is the effect of the organ on the upper left of this image?', 'text': 'Assistant: Breathe', 'answer_id': 'TYZQCKeCZnWw2Fr2HHMTeN', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Biotransformation, detoxification'}
# {'question_id': 12807, 'prompt': '\nWhich is smaller in this image,colon or liver?', 'text': 'Assistant: Liver', 'answer_id': 'WiGskgR4Psu5MRKjWgazPs', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Colon'}
# {'question_id': 12814, 'prompt': '\nWhat organ is the gray part on the right of the image?', 'text': 'Assistant: Spleen', 'answer_id': 'S98W2ZfJ3YU7Tcksf6SqcK', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Small Bowel'}
# {'question_id': 12823, 'prompt': '\nWhat organ is the black part on the upper left of the image?', 'text': 'Assistant: Right Kidney', 'answer_id': 'bR683AL5MNNoXM4iqY9Ypp', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Small Bowel'}
# {'question_id': 12839, 'prompt': '\nWhich is smaller in this image, spleen or kidney?', 'text': 'Assistant: Kidney', 'answer_id': 'SzxDqPACUzfT8SLKSMVxp7', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Spleen'}
# {'question_id': 12841, 'prompt': '\nWhat is the shape of spleen in the picture?', 'text': 'Assistant: Irregular', 'answer_id': 'ZaKg7FLg5524wsvNLaZxpL', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Oval'}
# {'question_id': 12854, 'prompt': '\nWhat is the function of the rightmost organ in this picture?', 'text': 'Assistant: Breathe', 'answer_id': 'Vgkw7RR3grLHjVwe2sPZC9', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': "Improve the body's immunity"}
# {'question_id': 12859, 'prompt': '\nWhere is the esophagus in this image?', 'text': 'Assistant: Top', 'answer_id': 'c5qvdkbpqw4cpMmBN8nPuv', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Center'}
# {'question_id': 12865, 'prompt': '\nHow many existing heart in this image?', 'text': 'Assistant: 0', 'answer_id': 'YGvMKYXiuAqVE5bgvRPpiU', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '1'}
# {'question_id': 12878, 'prompt': '\nWhere is the heart in this image,left,top or upper left?', 'text': 'Assistant: Left', 'answer_id': 'DFXsMrir2597bnvZv5QztM', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Top'}
# {'question_id': 12894, 'prompt': '\nHow many organs are there in this image?', 'text': 'Assistant: 5', 'answer_id': 'XYC8FP5ejHnBxptrQECY3W', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': '4'}
# {'question_id': 12898, 'prompt': '\nWhat modality is used to take this image?', 'text': 'Assistant: MRI', 'answer_id': 'agyZ6V9gpMHQw4dFX5n5gm', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'CT'}
# {'question_id': 12929, 'prompt': '\nWhich is bigger in this image, small bowel or colon?', 'text': 'Assistant: Colon', 'answer_id': 'k3F4CL2qEQPQ2zXyQWenoM', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Small Bowel'}
# {'question_id': 12946, 'prompt': '\nWhich part of the body does this image belong to?', 'text': 'Assistant: Head', 'answer_id': '6iD9Pmb6ALkbmwr954rszP', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'Brain'}
# {'question_id': 12951, 'prompt': '\nWhat diseases are included in the picture?', 'text': 'Assistant: Brain Edema', 'answer_id': 'gRBVEKde4CoeKWkcHVpckU', 'model_id': '/data/aofei/LLM/llava_med', 'metadata': {}, 'gt': 'None'}
