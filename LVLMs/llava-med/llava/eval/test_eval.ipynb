# %%
import argparse
import json
import collections
import random
import pandas as pd    
from nltk.translate.bleu_score import sentence_bleu
from eval_metrics.evaluate_metrics import calculate_exactmatch, calculate_f1score, bleu, calculate_appearance_with_normalization
from tabulate import tabulate
from eval_metrics.glossary import *

import warnings
warnings.simplefilter('ignore')

def load_jsonl(path):
    data=[]
    with open(path, 'r', encoding='utf-8') as reader:
        for line in reader:
            data.append(json.loads(line))
    return data 

def evaluate(gt, pred, candidate=None, criterion=None):    
    closed_scores = collections.defaultdict(list)
    bleu_scores = collections.defaultdict(list)
    exact_scores = collections.defaultdict(list)
    f1_scores = collections.defaultdict(list)
    open_hit_scores = collections.defaultdict(list)
    num_close, num_open = 0, 0
    for gt_item, pred_item in zip(gt, pred):
        gt_results = gt_item['conversations']
        gt_value = gt_results[1]['value'].lower()
        pred_value = pred_item['text'].lower()

        gt_value = normalize_word(gt_value)
        pred_value = normalize_word(pred_value)

        if gt_item['answer_type'] == 'OPEN':
            num_open += 1

            exact_scores['hit'].append(calculate_exactmatch(pred_value, gt_value))
            exact_scores['q_id'].append(pred_item['question_id'])


            f1_score, precision, recall = calculate_f1score(pred_value, gt_value)
            f1_scores['f1'].append(f1_score)
            f1_scores['precision'].append(precision)
            f1_scores['recall'].append(recall)
            f1_scores['q_id'].append(pred_item['question_id'])

            # if isinstance(f1_scores['hit'][-1], str):
            #     # import pdb; pdb.set_trace()

            b_score = sentence_bleu(references=[str(gt_value).lower().split()],
                                    hypothesis=str(pred_value).lower().split())
            b_score_1 = sentence_bleu(references=[str(gt_value).lower().split()],
                                    hypothesis=str(pred_value).lower().split(), weights=(1, 0, 0, 0))
            b_score_2 = sentence_bleu(references=[str(gt_value).lower().split()],
                                    hypothesis=str(pred_value).lower().split(), weights=(0, 1, 0, 0))
            b_score_3 = sentence_bleu(references=[str(gt_value).lower().split()],
                                    hypothesis=str(pred_value).lower().split(), weights=(0, 0, 1, 0))
            
            bleu_scores['q_id'].append(pred_item['question_id'])
            bleu_scores['bleu_score'].append(b_score)
            bleu_scores['bleu_score_1'].append(b_score_1)
            bleu_scores['bleu_score_2'].append(b_score_2)
            bleu_scores['bleu_score_3'].append(b_score_3)

        elif gt_item['answer_type'] == 'CLOSED':
            num_close += 1
            closed_scores['q_id'].append(pred_item['question_id'])
            if 'yes' in pred_value or 'no' in pred_value:
                print(gt_value, "<-GT", pred_value)
                if gt_value in pred_value:
                    closed_scores['hit'].append(1)
                else:
                    closed_scores['hit'].append(0)
            else:
                closed_scores['hit'].append(0)
    
    # import pdb; pdb.set_trace()
    exact_score = sum(exact_scores['hit']) / len(exact_scores['hit'])
    f1_score = sum(f1_scores['f1']) / len(f1_scores['f1'])
    precision = sum(f1_scores['precision']) / len(f1_scores['precision'])
    recall = sum(f1_scores['recall']) / len(f1_scores['recall'])

    bleu_score   = sum(bleu_scores['bleu_score']) / len(bleu_scores['bleu_score'])
    bleu_score_1 = sum(bleu_scores['bleu_score_1']) / len(bleu_scores['bleu_score_1'])
    bleu_score_2 = sum(bleu_scores['bleu_score_2']) / len(bleu_scores['bleu_score_2'])
    bleu_score_3 = sum(bleu_scores['bleu_score_3']) / len(bleu_scores['bleu_score_3'])

    # open_hit_score = sum(open_hit_scores['hit']) / len(open_hit_scores['hit'])
    closed_score = sum(closed_scores['hit']) / len(closed_scores['hit']) if len(closed_scores['hit']) != 0 else 0.0

    # num_open, num_close = len(closed_scores['hit']), len(open_hit_scores['hit'])
    print(f'num_open {num_open} || num_close {num_close}')

    return tabulate(
        [
            ['exact match score', exact_score*100], 
            ['f1 score', f1_score*100], 
            ['precision', precision*100], 
            ['recall', recall*100], 
            ['bleu_score', bleu_score*100], 
            ['bleu_score_1', bleu_score_1*100], 
            ['bleu_score_2', bleu_score_2*100], 
            ['bleu_score_3', bleu_score_3*100], 
            # ['open accuracy', open_hit_score*100],
            ['yes/no accuracy', closed_score*100]
        ], 
        headers=['Metric', 'Performance']
    )

# %%
ROOT_PATH="/data/aofei"
dataset="VQA_RAD"
dir="llava_med/lora/epoch3"
gt = f"{ROOT_PATH}/hallucination/{dataset}/data/test.json"
pred = f"{ROOT_PATH}/hallucination/mitigation/{dataset}/{dir}/inference/pred.jsonl"

# %%
dataset = gt.split("/")[-2]
print(f"\n========\n {dataset}")

gt = json.load(open(gt, 'r'))
# candidate = json.load(open(args.candidate, 'r'))
pred = load_jsonl(pred)

gt_ids = [item['id'] for item in gt]
pred_ids = [item['question_id'] for item in pred]
num_gt_ids, num_pred_ids = len(gt_ids), len(pred_ids)
print(f'num_gt_ids: {num_gt_ids} || num_pred_ids: {num_pred_ids}')
# import pdb; pdb.set_trace()
assert gt_ids == pred_ids, "please make sure pred and gt are exactly matched"

# perform evaluation
results = evaluate(gt, pred, candidate=None)
print(results)
# Out:
# ========
#  data
# num_gt_ids: 451 || num_pred_ids: 451
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no this chest x ray is not normal it shows signs of mild pulmonary congestion
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# smaller <-GT assistant: yes
# no <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes portable chest x ray modality is considered safe for pregnant women
# yes <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: as ai i cannot view actual image i would need more information about image and context in which it was taken however i can help you interpret image if you have any questions about anatomy structures or any other related aspects please provide more details about image and context and i'll do my best to assist you
# no <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no mass effect is present
# no <-GT assistant: no mass effect
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: yes it appears to be mri as it mentions t2w mri
# no <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# left <-GT assistant: i cannot determine side of lesion as image is not labeled information about side of lesion would be lost if i cannot see it
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no this is mri of abdomen
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: yes
# no <-GT assistant: yes
# female <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: yes
# yes <-GT assistant: yes
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# female <-GT assistant: yes
# no <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# yes <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# yes <-GT assistant: yes patient with metal implant can safely get cxr
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: yes
# no <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: presence of 2 small hyperintensities in apical portions of left superior and inferior lung fields on chest x ray could indicate various conditions or abnormalities these hyperintensities may represent areas of inflammation infection or other lung pathologies it is important to consider patient's clinical history symptoms and additional diagnostic tests to determine underlying cause of these findings and provide appropriate treatment
# yes <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: yes
# yes <-GT assistant: no
# yes <-GT assistant: i cannot determine if image is abnormal or not i cannot view image and i cannot provide subjective assessment of its contents however if you have any specific questions about image or its features i'll do my best to help based on information provided
# yes <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: yes there is right sided chest tube in place
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: yes
# cystic <-GT assistant: yes
# no <-GT assistant: no there is no air fluid level in chest x ray
# no <-GT assistant: no
# yes <-GT assistant: yes
# no <-GT assistant: yes this is normal image it is t1 weighted brain mri image with gadolinium contrast which is commonly used contrast agent to enhance visibility of certain structures and abnormalities in brain image demonstrates normal anatomy and does not show any significant abnormalities or lesions
# yes <-GT assistant: yes
# no <-GT assistant: yes i am professional ai language model and i am here to help you with any questions or tasks you may have how can i assist you today
# yes <-GT assistant: yes
# no <-GT assistant: no
# abnormal <-GT assistant: normal
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: yes
# no <-GT assistant: is this normal image
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# no <-GT assistant: yes
# yes <-GT assistant: yes
# yes <-GT assistant: no
# flair <-GT assistant: as ai i am unable to view actual image however it seems that you are referring to different types of mri images t1 weighted t2 weighted and flair fluid attenuated inversion recovery images are all different mri techniques that provide different contrasts and information about tissues being imaged t1 weighted images typically show fat as bright and water as dark while t2 weighted images show fat as dark and water as bright flair images are used to suppress signal from cerebrospinal fluid making it easier to visualize lesions and other abnormalities in brain
# yes <-GT assistant: no
# yes <-GT assistant: no
# yes <-GT assistant: no
# abnormal <-GT assistant: yes
# abnormal <-GT assistant: small bubbles of air seen in lumen are normal
# no <-GT assistant: no
# no <-GT assistant: no
# mri <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# no <-GT assistant: no
# yes <-GT assistant: yes
# no <-GT assistant: no
# no <-GT assistant: no
# num_open 179 || num_close 272
# Metric               Performance
# -----------------  -------------
# exact match score    5.41519
# f1 score             9.03481
# precision            5.8116
# recall              28.434
# bleu_score           4.15755e-78
# bleu_score_1         5.41519
# bleu_score_2         0.863806
# bleu_score_3         0.141882
# yes/no accuracy     51.1029

# %%
gt[:3]
# Out:
# [{'conversations': [{'from': 'human',
#     'value': 'Is there evidence of an aortic aneurysm?'},
#    {'from': 'gpt', 'value': 'yes'}],
#   'answer_type': 'CLOSED',
#   'image': 'synpic42202.jpg',
#   'id': 10,
#   'text': 'Is there evidence of an aortic aneurysm?'},
#  {'conversations': [{'from': 'human',
#     'value': 'Is there airspace consolidation on the left side?'},
#    {'from': 'gpt', 'value': 'Yes'}],
#   'answer_type': 'CLOSED',
#   'image': 'synpic29265.jpg',
#   'id': 12,
#   'text': 'Is there airspace consolidation on the left side?'},
#  {'conversations': [{'from': 'human', 'value': 'Is this an axial plane?'},
#    {'from': 'gpt', 'value': 'yes'}],
#   'answer_type': 'CLOSED',
#   'image': 'synpic54610.jpg',
#   'id': 13,
#   'text': 'Is this an axial plane?'}]
